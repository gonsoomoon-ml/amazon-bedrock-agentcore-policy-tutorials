# %% [markdown]
# # Amazon Bedrock AgentCore Policy - MCP 서버 타겟 설정
#
# ## 개요
#
# 이 노트북은 OAuth 인증을 사용하여 **AgentCore Runtime**에 배포된 **MCP 서버 타겟**과 함께 **Amazon Bedrock AgentCore Policy**를 테스트하기 위한 인프라를 설정합니다.
#
# ### 노트북 구조
#
# | Part | 제목 | 내용 |
# |------|------|------|
# | 1 | 환경 설정 | 라이브러리 로드, 설정 변수 |
# | 2 | Runtime 배포 | Cognito 설정 + MCP 서버 배포 |
# | 3 | Runtime 설정 로드 | 설정 파일 읽기 |
# | 4 | Runtime 상태 확인 | READY 상태 확인 |
# | 5 | Runtime 직접 테스트 | MCP 서버 동작 검증 (선택사항) |
# | 6 | Gateway 설정 | Gateway 생성, Identity, MCP 타겟 |
# | 7 | 설정 저장 | `runtime_config.json` 업데이트 |
# | 8 | 설정 확인 | Gateway 통한 도구 호출 테스트 |
#
# ### 이 튜토리얼에서 다루는 컴포넌트
#
# | 컴포넌트 | 역할 |
# |----------|------|
# | **Runtime** | MCP 서버 호스팅 (컨테이너 기반) |
# | **Gateway** | MCP 프로토콜 엔드포인트, 도구 호출 중개 |
# | **Identity** | Outbound Auth를 위한 자격 증명 관리 |
# | **Policy** | Cedar 기반 세분화된 접근 제어 (다음 노트북) |
#
# ### Inbound Auth vs Outbound Auth
#
# | 인증 유형 | 방향 | 방식 |
# |----------|------|------|
# | **Inbound Auth** | 클라이언트 → Gateway | JWT 토큰 **검증** |
# | **Outbound Auth** | Gateway → Runtime | OAuth 토큰 **발급** |
#
# ### 전체 인증 흐름
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────────────────┐
# │                              전체 인증 흐름                                          │
# ├─────────────────────────────────────────────────────────────────────────────────────┤
# │                                                                                      │
# │  ┌────────────┐                                                                      │
# │  │  Gateway   │                                                                      │
# │  │  Cognito   │                                                                      │
# │  └─────┬──────┘                                                                      │
# │        │ 1. JWT 토큰 발급                                                             │
# │        ▼                                                                             │
# │  ┌────────────┐      2. JWT 토큰      ┌────────────┐                                 │
# │  │  클라이언트 │ ───────────────────> │  Gateway   │                                 │
# │  │  (Agent)   │                       │            │                                 │
# │  └────────────┘                       └─────┬──────┘                                 │
# │                                             │                                        │
# │                                             │ 3. JWT Authorizer가 토큰 검증           │
# │                                             │                                        │
# │                                             │ 4. Identity에서 자격 증명 조회          │
# │                                             ▼                                        │
# │                                       ┌────────────┐                                 │
# │                                       │  Identity  │                                 │
# │                                       │ (Resource  │                                 │
# │                                       │ Credential │                                 │
# │                                       │ Provider)  │                                 │
# │                                       └─────┬──────┘                                 │
# │                                             │                                        │
# │                                             │ 5. client_id, client_secret 반환       │
# │                                             ▼                                        │
# │                                       ┌────────────┐                                 │
# │                                       │  Runtime   │                                 │
# │                                       │  Cognito   │                                 │
# │                                       └─────┬──────┘                                 │
# │                                             │                                        │
# │                                             │ 6. OAuth Access Token 발급             │
# │                                             ▼                                        │
# │  ┌────────────┐      7. 결과 반환     ┌────────────┐      8. OAuth 토큰      ┌──────────┐
# │  │  클라이언트 │ <───────────────────  │  Gateway   │ ───────────────────> │ Runtime  │
# │  │            │                       │            │     (MCP 요청)       │(MCP 서버)│
# │  └────────────┘                       └────────────┘                       └──────────┘
# │                                                                                      │
# └─────────────────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### 단계별 설명
#
# | 단계 | 설명 | 컴포넌트 |
# |------|------|----------|
# | 1 | 클라이언트가 Gateway Cognito에서 JWT 토큰 발급받음 | Gateway Cognito |
# | 2 | 클라이언트가 JWT 토큰과 함께 Gateway에 요청 | 클라이언트 → Gateway |
# | 3 | JWT Authorizer가 토큰 검증 (서명, 만료, 클레임) | Gateway |
# | 4-5 | Gateway가 Identity에서 Runtime 자격 증명 조회 | Gateway → Identity |
# | 6 | Gateway가 Runtime Cognito에서 OAuth 토큰 발급받음 | Runtime Cognito |
# | 7-8 | Gateway가 OAuth 토큰으로 Runtime(MCP 서버)에 요청 | Gateway → Runtime |
#
# ### 이 노트북에서 생성하는 리소스
#
# | 리소스 | 설명 |
# |--------|------|
# | AgentCore Runtime | MCP 서버를 호스팅하는 컨테이너 |
# | MCP 서버 | 환불/청구 도구가 포함된 FastMCP 서버 |
# | Cognito (Runtime) | Runtime Inbound Auth |
# | Cognito (Gateway) | Gateway Inbound Auth |
# | AgentCore Gateway | JWT Authorizer 포함 |
# | AgentCore Identity | Outbound Auth용 Resource Credential Provider |
# | Gateway 타겟 | Identity를 통해 연결된 MCP 서버 |
#
# > **참고**: Gateway와 Gateway Cognito는 `01-Lambda-Target/setup-gateway.py`를 통해 생성됩니다.
#
# > **다음 단계**: 이 노트북 완료 후, `02-Policy-Enforcement.ipynb`에서 Cedar 정책을 테스트하세요.
#
# ### 관련 문서
#
# - [AgentCore Identity 가이드](../docs/agentcore-identity.md) - Identity 개념 상세 설명
# - [JWT Authorizer](../docs/jwt-authorizer.md) - Inbound Auth 상세
# - [Cognito](../docs/cognito.md) - Amazon Cognito 설정
#
# ---

# %% [markdown]
# ## Part 1: 환경 설정
#
# > 환경 설정이 완료되지 않은 경우, [00_setup/README.md](../00_setup/README.md)를 참고하세요.
#
# ### 사전 요구사항
#
# - **Docker** 실행 중 (컨테이너 빌드용)
# - AWS 자격 증명 설정됨
#
# VS Code에서 `AgentCorePolicy` 커널이 선택되었는지 확인하세요.

# %%
import json
import sys
import time
import os
from pathlib import Path
from urllib.parse import quote

import boto3
import requests

# Add parent directory to path for common imports
sys.path.insert(0, str(Path.cwd().parent))

from common.auth_utils import get_bearer_token, decode_token

print("✓ Libraries loaded")

# %%
# Configuration
REGION = "us-east-1"
RUNTIME_NAME = "refund_mcp_server"
MCP_TARGET_NAME = "RefundMCPServerTarget"
SCRIPT_DIR = Path.cwd()

print(f"Region: {REGION}")
print(f"Runtime Name: {RUNTIME_NAME}")
print(f"Script Directory: {SCRIPT_DIR}")

# %% [markdown]
# ---
#
# ## Part 2: MCP 서버를 AgentCore Runtime에 배포
#
# ### `setup_cognito_and_deploy_mcp_server_runtime.py` 스크립트
#
# 이 스크립트는 두 가지 주요 작업을 수행합니다:
#
# #### 1. Cognito 설정 (Runtime OAuth용)
#
# | 단계 | 리소스 | 설명 |
# |------|--------|------|
# | 1 | User Pool | OAuth 인증의 기반 |
# | 2 | Domain | 토큰 엔드포인트 URL 제공 |
# | 3 | Resource Server | `refund-mcp/invoke` scope 정의 |
# | 4 | App Client | Client Credentials 플로우용 |
#
# #### 2. Runtime 배포 (Starter Toolkit 사용)
#
# | 단계 | 작업 | 설명 |
# |------|------|------|
# | 1 | Dockerfile 생성 | MCP 서버 컨테이너 설정 |
# | 2 | Docker 빌드 | 로컬에서 이미지 빌드 |
# | 3 | ECR 푸시 | AWS ECR에 이미지 업로드 |
# | 4 | Runtime 생성 | AgentCore Runtime 생성 (JWT Authorizer 포함) |
# | 5 | READY 대기 | Runtime이 준비될 때까지 대기 |
#
# #### 생성되는 파일
#
# | 파일 | 내용 |
# |------|------|
# | `cognito_config.json` | Runtime Cognito 자격 증명 |
# | `runtime_config.json` | Runtime ID, ARN, MCP URL |
#
# > ⏱️ 첫 번째 배포 시 약 **5-10분** 소요됩니다.

# %%
# Check if runtime is already deployed
runtime_config_file = SCRIPT_DIR / "runtime_config.json"
cognito_config_file = SCRIPT_DIR / "cognito_config.json"

if runtime_config_file.exists() and cognito_config_file.exists():
    print("✓ Runtime configuration already exists")
    print(f"  Config file: {runtime_config_file}")
    
    with open(runtime_config_file, "r") as f:
        runtime_config = json.load(f)
    print(f"  Runtime ID: {runtime_config.get('runtime_id')}")
    
    SKIP_DEPLOYMENT = True
else:
    print("Runtime not deployed yet. Will deploy in next cell.")
    SKIP_DEPLOYMENT = False

# %%
# Deploy MCP Runtime (skip if already deployed)
if not SKIP_DEPLOYMENT:
    print("Deploying MCP Server to AgentCore Runtime...")
    print("This will take 5-10 minutes.")
    print("=" * 70)
    
    # %run setup_cognito_and_deploy_mcp_server_runtime.py
else:
    print("✓ Skipping deployment - runtime already exists")

# %% [markdown]
# ### 배포 결과 확인
#
# #### (1) 생성된 Cognito User Pool
# ![refund_mcp_server_pool.png](img/refund_mcp_server_pool.png)
#
# #### (2) AgentCore Runtime에 배포된 MCP 서버
# ![runtime_mcp_server.png](img/runtime_mcp_server.png)
#
# #### (3) AgentCore Runtime에 배포된 MCP 서버의 Version 1
#
# Runtime의 **Inbound Auth** 설정은 Cognito Pool ID 기반의 Discovery URL을 사용합니다:
#
# ```
# Discovery URL: https://cognito-idp.{region}.amazonaws.com/{pool_id}/.well-known/openid-configuration
# ```
#
# 이를 통해 Runtime은:
# - 들어오는 JWT 토큰의 **서명**을 Cognito 공개 키로 검증
# - 토큰의 **만료 시간** 확인
# - **allowedClients**에 등록된 Client ID 확인
#
# #### JWT 서명 검증 과정
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────────┐
# │  JWT 서명 검증 흐름                                                          │
# ├─────────────────────────────────────────────────────────────────────────────┤
# │                                                                              │
# │  1. Discovery URL 조회                                                       │
# │     https://cognito-idp.{region}.amazonaws.com/{pool_id}/.well-known/openid-configuration
# │                              │                                               │
# │                              ▼                                               │
# │  2. JWKS URI 획득 (Discovery 응답에서)                                        │
# │     https://cognito-idp.{region}.amazonaws.com/{pool_id}/.well-known/jwks.json
# │                              │                                               │
# │                              ▼                                               │
# │  3. 공개 키 다운로드 (JWKS = JSON Web Key Set)                                │
# │     { "keys": [{ "kid": "...", "kty": "RSA", "n": "...", "e": "..." }] }     │
# │                              │                                               │
# │                              ▼                                               │
# │  4. JWT 헤더의 kid와 매칭되는 공개 키로 서명 검증                               │
# │     JWT: header.payload.signature                                            │
# │          └─ kid ───────────────────────────────────────────┘                 │
# │                                                                              │
# └─────────────────────────────────────────────────────────────────────────────┘
# ```
#
# > **JWKS (JSON Web Key Set)**: Cognito가 JWT 서명에 사용한 **비밀 키**에 대응하는 **공개 키** 세트입니다. Runtime은 이 공개 키로 토큰이 위조되지 않았음을 검증합니다.
#
# ![mcp_server_runtime_version_1.png](img/mcp_server_runtime_version_1.png)

# %% [markdown]
# ---
#
# ## Part 3: Runtime 설정 로드

# %%
# Load Runtime config
with open(runtime_config_file, "r") as f:
    RUNTIME_CONFIG = json.load(f)

# Load Cognito config (for Runtime OAuth)
with open(cognito_config_file, "r") as f:
    COGNITO_CONFIG = json.load(f)

RUNTIME_ID = RUNTIME_CONFIG["runtime_id"]
RUNTIME_ARN = RUNTIME_CONFIG["runtime_arn"]
RUNTIME_URL = RUNTIME_CONFIG.get("runtime_url") or RUNTIME_CONFIG.get("mcp_url")  # 하위 호환

print("✓ Configuration loaded")
print(f"  Runtime ID: {RUNTIME_ID}")
print(f"  Runtime ARN: {RUNTIME_ARN}")
print(f"  Runtime URL: {RUNTIME_URL[:80]}...")

# %% [markdown]
# ---
#
# ## Part 4: Runtime이 준비되었는지 확인

# %%
# Initialize AWS client
session = boto3.Session(region_name=REGION)
agentcore_client = session.client("bedrock-agentcore-control")
sts_client = session.client("sts")

ACCOUNT_ID = sts_client.get_caller_identity()["Account"]

print("✓ AWS clients initialized")
print(f"  Account ID: {ACCOUNT_ID}")

# %%
# Check Runtime status
runtime_details = agentcore_client.get_agent_runtime(agentRuntimeId=RUNTIME_ID)
runtime_status = runtime_details.get("status")

print(f"Runtime Status: {runtime_status}")

if runtime_status == "READY":
    print("\n✓ Runtime is READY")
else:
    print(f"\n⚠️  Runtime status: {runtime_status}")
    print("   Please wait for runtime to be READY before continuing.")

# %% [markdown]
# ---
#
# ## Part 5: Runtime 직접 테스트 (선택사항)
#
# Gateway에 연결하기 전에 MCP 서버가 올바르게 응답하는지 테스트합니다.
#
# ### 테스트 흐름
#
# ```
# ┌────────────┐      Bearer Token      ┌────────────┐
# │  노트북     │ ────────────────────> │  Runtime   │
# │  (클라이언트)│      + MCP 요청       │ (MCP 서버)  │
# └────────────┘                        └────────────┘
# ```
#
# ### MCP 프로토콜 요청/응답
#
# | 항목 | 내용 |
# |------|------|
# | **Method** | `tools/list` - 사용 가능한 도구 목록 조회 |
# | **Accept Header** | `application/json, text/event-stream` (필수) |
# | **응답 형식** | Server-Sent Events (SSE) |
#
# ### SSE 응답 형식
#
# Runtime은 **Server-Sent Events** 형식으로 응답합니다:
#
# ```
# event: message
# data: {"jsonrpc":"2.0","id":1,"result":{"tools":[...]}}
# ```
#
# 따라서 `data:` 라인에서 JSON을 추출하여 파싱해야 합니다.

# %%
# Get token for Runtime
token = get_bearer_token(
    token_endpoint=COGNITO_CONFIG["token_endpoint"],
    client_id=COGNITO_CONFIG["client_id"],
    client_secret=COGNITO_CONFIG["client_secret"],
    scope=COGNITO_CONFIG["scope"]
)

print(f"✓ Token received ({len(token)} chars)")

# %%
# Test tools/list on Runtime directly
print("Testing MCP Server...")
print("=" * 70)

payload = {
    "jsonrpc": "2.0",
    "id": 1,
    "method": "tools/list",
    "params": {}
}

response = requests.post(
    RUNTIME_URL,
    headers={
        "Content-Type": "application/json",
        "Authorization": f"Bearer {token}",
        "Accept": "application/json, text/event-stream",  # MCP 필수 헤더
    },
    json=payload,
    timeout=30
)

print(f"Status: {response.status_code}")

# SSE 형식 파싱 (event: message\ndata: {...})
def parse_sse_response(text):
    """Server-Sent Events 형식에서 JSON 데이터 추출"""
    for line in text.split('\n'):
        if line.startswith('data: '):
            return json.loads(line[6:])  # 'data: ' 제거
    return None

if response.text:
    result = parse_sse_response(response.text)
    if result and "result" in result:
        tools = result["result"].get("tools", [])
        print(f"\n✓ MCP Server responding with {len(tools)} tools:")
        for tool in tools:
            print(f"  - {tool['name']}")
    elif result and "error" in result:
        print(f"\n⚠️  Error: {result['error']}")
    else:
        print(f"\n⚠️  Unexpected response format")
        print(response.text[:300])
else:
    print("\n⚠️  Empty response from server")

# %% [markdown]
# ---
#
# ## Part 6: MCP 타겟과 함께 Gateway 설정
#
# ### 개요
#
# 이 섹션에서는 Gateway에 MCP 서버 타겟을 추가합니다.
#
# ### 수행 단계
#
# | 단계 | 셀 | 작업 | 설명 |
# |------|-----|------|------|
# | 1 | cell-17 | Gateway 생성 | `setup-gateway.py` 실행 (없는 경우) |
# | 2 | cell-19 | Gateway 설정 추출 | Gateway ID, URL, Cognito 정보 저장 |
# | 3 | cell-21 | Identity 생성 | Outbound Auth용 Resource Credential Provider |
# | 4 | cell-23 | MCP 타겟 생성 | Runtime URL을 타겟으로 등록 |
# | 5 | cell-24 | 타겟 READY 대기 | 타겟 상태 확인 |
# | 6 | cell-25 | 도구 동기화 | MCP 서버에서 도구 목록 가져오기 |
#
# ### Lambda 타겟에 대해
#
# `setup-gateway.py`는 **Lambda 타겟**(`RefundToolTarget`)도 함께 생성합니다. 이는 `01-Lambda-Target` 튜토리얼과 Gateway를 공유하기 위함입니다.
#
# ```
# Gateway
# ├── RefundToolTarget (Lambda)     ← 01-Lambda-Target에서 사용
# └── RefundMCPServerTarget (MCP)   ← 이 튜토리얼에서 사용
# ```
#
# 두 타겟은 동일한 Gateway에 공존할 수 있으며, 서로 간섭하지 않습니다. 이 튜토리얼에서는 **MCP 타겟**만 사용합니다.

# %%
# Check for existing Gateway config, create if needed
lambda_target_dir = Path.cwd().parent / "01-Lambda-Target"
gateway_config_file = lambda_target_dir / "gateway_config.json"

if not gateway_config_file.exists():
    print("Gateway not found. Creating via setup-gateway.py...")
    print("=" * 70)
    
    # Run setup script from 01-Lambda-Target directory
    original_dir = os.getcwd()
    os.chdir(lambda_target_dir)
    # %run setup-gateway.py --region us-east-1
    os.chdir(original_dir)
    
    print("\n✓ Gateway created")
else:
    print(f"✓ Using existing Gateway config: {gateway_config_file}")

# Load Gateway config
with open(gateway_config_file, "r") as f:
    GATEWAY_CONFIG = json.load(f)

print(f"  Gateway ID: {GATEWAY_CONFIG['gateway_id']}")

# %% [markdown]
# #### (1) 생성된 Gateway
# ![gateway_mcp.png](img/gateway_mcp.png)

# %%
# Extract Gateway configuration
GATEWAY_ID = GATEWAY_CONFIG["gateway_id"]
GATEWAY_URL = GATEWAY_CONFIG["gateway_url"]
GATEWAY_ARN = GATEWAY_CONFIG["gateway_arn"]

# Save Gateway Cognito config for this tutorial
gateway_cognito_config = {
    "client_id": GATEWAY_CONFIG["client_info"]["client_id"],
    "client_secret": GATEWAY_CONFIG["client_info"]["client_secret"],
    "token_endpoint": GATEWAY_CONFIG["client_info"]["token_endpoint"],
    "scope": GATEWAY_CONFIG["client_info"].get("scope", "")
}

gateway_cognito_file = SCRIPT_DIR / "gateway_cognito_config.json"
with open(gateway_cognito_file, "w") as f:
    json.dump(gateway_cognito_config, f, indent=2)

print("✓ Gateway configuration ready")
print(f"  Gateway ID: {GATEWAY_ID}")
print(f"  Gateway URL: {GATEWAY_URL}")

# %% [markdown]
# ### AgentCore Identity (Resource Credential Provider) 생성
#
# AgentCore Gateway가 MCP 서버(AgentCore Runtime)에 대한 **Outbound Auth**로 사용할 Resource Credential Provider를 생성합니다.
#
# #### Identity란?
#
# Gateway가 외부 서비스(Runtime)를 호출할 때 필요한 **자격 증명을 안전하게 저장하고 관리**하는 컴포넌트입니다.
#
# #### 저장되는 정보
#
# | 항목 | 값 | 용도 |
# |------|-----|------|
# | `discoveryUrl` | Runtime Cognito Discovery URL | 토큰 엔드포인트 조회 |
# | `clientId` | Runtime Cognito App Client ID | OAuth 인증 |
# | `clientSecret` | Runtime Cognito App Client Secret | OAuth 인증 |
#
# #### 흐름
#
# ```
# Gateway가 MCP 호출 시:
# 1. Identity에서 clientId, clientSecret 조회
# 2. discoveryUrl에서 token_endpoint 획득
# 3. Runtime Cognito에 Client Credentials로 토큰 요청
# 4. 발급받은 Access Token으로 Runtime 호출
# ```
#
# #### 두 개의 Cognito Pool
#
# 이 튜토리얼에서는 **두 개의 Cognito User Pool**이 사용됩니다:
#
# | Cognito | 용도 | 저장 위치 |
# |---------|------|-----------|
# | **Gateway Cognito** | 클라이언트 → Gateway (Inbound Auth) | `gateway_cognito_config.json` |
# | **Runtime Cognito** | Gateway → Runtime (Outbound Auth) | `cognito_config.json` |
#
# ```
# ┌─────────────┐                      ┌─────────────┐                      ┌─────────────┐
# │   Gateway   │   JWT 발급           │   Runtime   │   OAuth 토큰 발급    │   Runtime   │
# │   Cognito   │ ──────────────────>  │   Cognito   │ ──────────────────>  │  (MCP 서버) │
# └─────────────┘   (클라이언트용)      └─────────────┘   (Gateway용)        └─────────────┘
#        │                                    │
#        │                                    │
#        ▼                                    ▼
#   Inbound Auth                      Identity에 저장됨
#   (JWT Authorizer)                  (clientId, clientSecret)
# ```
#
# > **중요**: Identity에 저장된 `clientId`, `clientSecret`은 **Runtime Cognito**의 자격 증명입니다. 클라이언트가 Gateway에 접근할 때 사용하는 **Gateway Cognito** 자격 증명과 다릅니다.

# %%
# Create OAuth Credential Provider (공식 샘플 패턴)
CREDENTIAL_PROVIDER_NAME = "refund-mcp-server-identity"

# Check if credential provider already exists
try:
    existing_providers = agentcore_client.list_oauth2_credential_providers().get("oauth2CredentialProviders", [])
    
    existing_provider = next(
        (p for p in existing_providers if p["name"] == CREDENTIAL_PROVIDER_NAME),
        None
    )
except Exception as e:
    existing_provider = None
    print(f"Note: {e}")

if existing_provider:
    CREDENTIAL_PROVIDER_ARN = existing_provider["credentialProviderArn"]
    print(f"✓ Using existing Credential Provider: {CREDENTIAL_PROVIDER_NAME}")
    print(f"  ARN: {CREDENTIAL_PROVIDER_ARN}")
else:
    print(f"Creating OAuth Credential Provider: {CREDENTIAL_PROVIDER_NAME}")
    
    try:
        # 공식 샘플 패턴: clientId/clientSecret을 생성 시 포함
        response = agentcore_client.create_oauth2_credential_provider(
            name=CREDENTIAL_PROVIDER_NAME,
            credentialProviderVendor="CustomOauth2",
            oauth2ProviderConfigInput={
                "customOauth2ProviderConfig": {
                    "oauthDiscovery": {
                        "discoveryUrl": COGNITO_CONFIG["discovery_url"]
                    },
                    "clientId": COGNITO_CONFIG["client_id"],
                    "clientSecret": COGNITO_CONFIG["client_secret"]
                }
            }
        )
        CREDENTIAL_PROVIDER_ARN = response["credentialProviderArn"]
        print(f"✓ Credential Provider created")
        print(f"  ARN: {CREDENTIAL_PROVIDER_ARN}")
    except Exception as e:
        print(f"⚠️  Error creating credential provider: {e}")
        CREDENTIAL_PROVIDER_ARN = None

# %% [markdown]
# ### Gateway에 MCP 서버 타겟 생성
#
# 아래 셀은 `create_gateway_target` API를 호출하여 MCP 서버를 Gateway 타겟으로 등록합니다.
#
# #### 주요 파라미터
#
# | 파라미터 | 값 | 설명 |
# |----------|-----|------|
# | `name` | `RefundMCPServerTarget` | 타겟 이름 (도구 호출 시 prefix로 사용) |
# | `targetConfiguration.mcp.mcpServer.endpoint` | Runtime URL | MCP 서버의 호출 URL |
# | `credentialProviderType` | `OAUTH` | Outbound Auth 방식 |
# | `providerArn` | Identity ARN | Resource Credential Provider |
# | `scopes` | `["refund-mcp/invoke"]` | OAuth scope |
#
# #### 도구 이름 규칙
#
# Gateway에서 MCP 도구를 호출할 때는 다음 형식을 사용합니다:
#
# ```
# {TargetName}___{tool_name}
# ```
#
# 예시:
# - `RefundMCPServerTarget___refund`
# - `RefundMCPServerTarget___get_order`
# - `RefundMCPServerTarget___approve_claim`

# %%
# Check for existing MCP target
existing_targets = agentcore_client.list_gateway_targets(
    gatewayIdentifier=GATEWAY_ID
).get("targets", [])

mcp_target = next(
    (t for t in existing_targets if t.get("name") == MCP_TARGET_NAME),
    None
)

if mcp_target:
    MCP_TARGET_ID = mcp_target["targetId"]
    print(f"✓ Using existing MCP Target: {MCP_TARGET_NAME}")
    print(f"  Target ID: {MCP_TARGET_ID}")
    print(f"  Status: {mcp_target.get('status')}")
else:
    print(f"Creating MCP Server Target: {MCP_TARGET_NAME}")
    
    # 공식 샘플 패턴: endpoint 키 사용, OAUTH 타입
    response = agentcore_client.create_gateway_target(
        gatewayIdentifier=GATEWAY_ID,
        name=MCP_TARGET_NAME,
        description="MCP Server for policy testing",
        targetConfiguration={
            "mcp": {
                "mcpServer": {
                    "endpoint": RUNTIME_URL  # Runtime Invocation URL
                }
            }
        },
        credentialProviderConfigurations=[
            {
                "credentialProviderType": "OAUTH",  # 공식 샘플: "OAUTH"
                "credentialProvider": {
                    "oauthCredentialProvider": {
                        "providerArn": CREDENTIAL_PROVIDER_ARN,
                        "scopes": [COGNITO_CONFIG["scope"]]
                    }
                }
            }
        ]
    )
    
    MCP_TARGET_ID = response["targetId"]
    print(f"✓ MCP Target created")
    print(f"  Target ID: {MCP_TARGET_ID}")

# %%
# Synchronize target to discover tools
print("Synchronizing target to discover tools...")

try:
    agentcore_client.synchronize_gateway_targets(
        gatewayIdentifier=GATEWAY_ID,
        targetIdList=[MCP_TARGET_ID]  # targetId → targetIdList (리스트)
    )
    print("✓ Synchronization initiated")
    print("  Waiting for sync to complete...")
    time.sleep(15)
except Exception as e:
    print(f"⚠️  Sync error: {e}")

# %% [markdown]
# #### (1) Gateway MCP Target 생성 (RefundMCPServerTarget)
# ![gateway_mcp_target.png](img/gateway_mcp_target.png)

# %% [markdown]
# ---
#
# ## Part 7: 설정 저장
#
# `runtime_config.json`에 Gateway 및 Target 정보를 추가로 저장합니다.
#
# ### 저장되는 정보
#
# | 항목 | 설명 |
# |------|------|
# | `gateway_id` | Gateway 식별자 |
# | `gateway_url` | Gateway MCP 엔드포인트 URL |
# | `gateway_arn` | Gateway ARN |
# | `target_id` | MCP Target 식별자 |
# | `credential_provider_arn` | Identity (Resource Credential Provider) ARN |
# | `credential_provider_name` | Identity 이름 (cleanup용) |
#
# 이 정보는 `02-Policy-Enforcement.ipynb`에서 사용됩니다.

# %%
# Update runtime_config.json with Gateway and Target info
RUNTIME_CONFIG["gateway_id"] = GATEWAY_ID
RUNTIME_CONFIG["gateway_url"] = GATEWAY_URL
RUNTIME_CONFIG["gateway_arn"] = GATEWAY_ARN
RUNTIME_CONFIG["target_id"] = MCP_TARGET_ID
RUNTIME_CONFIG["credential_provider_arn"] = CREDENTIAL_PROVIDER_ARN
RUNTIME_CONFIG["credential_provider_name"] = CREDENTIAL_PROVIDER_NAME  # cleanup용

with open(runtime_config_file, "w") as f:
    json.dump(RUNTIME_CONFIG, f, indent=2)

print("✓ Configuration saved to runtime_config.json")

# %% [markdown]
# ---
#
# ## Part 8: 설정 확인
#
# Gateway를 통해 MCP 도구를 호출할 수 있는지 테스트합니다.
#
# ### 테스트 흐름
#
# ```
# ┌─────────────┐                      ┌─────────────┐                      ┌─────────────┐
# │   노트북     │                      │   Gateway   │                      │   Runtime   │
# │  (클라이언트) │                      │             │                      │  (MCP 서버)  │
# └──────┬──────┘                      └──────┬──────┘                      └──────┬──────┘
#        │                                    │                                    │
#        │ 1. Gateway Cognito에서             │                                    │
#        │    JWT 토큰 발급                    │                                    │
#        │                                    │                                    │
#        │ 2. JWT 토큰 + tools/call 요청       │                                    │
#        │ ─────────────────────────────────> │                                    │
#        │                                    │                                    │
#        │                                    │ 3. JWT Authorizer가 토큰 검증        │
#        │                                    │                                    │
#        │                                    │ 4. Identity에서 Runtime 자격 증명    │
#        │                                    │    (clientId, clientSecret) 조회    │
#        │                                    │                                    │
#        │                                    │ 5. Runtime Cognito에서              │
#        │                                    │    OAuth 토큰 발급                   │
#        │                                    │                                    │
#        │                                    │ 6. OAuth 토큰 + MCP 요청             │
#        │                                    │ ─────────────────────────────────> │
#        │                                    │                                    │
#        │                                    │ 7. MCP 응답                         │
#        │                                    │ <───────────────────────────────── │
#        │                                    │                                    │
#        │ 8. JSON-RPC 응답                    │                                    │
#        │ <───────────────────────────────── │                                    │
#        │                                    │                                    │
#        ▼                                    ▼                                    ▼
# ```
#
# ### 수행 단계
#
# | 셀 | 작업 | 설명 |
# |----|------|------|
# | cell-29 | Gateway 토큰 발급 | Gateway Cognito에서 JWT 토큰 획득 |
# | cell-30 | 도구 호출 테스트 | `approve_claim` 도구 호출 |
#
# ### 테스트 도구: `approve_claim`
#
# | 파라미터 | 값 | 설명 |
# |----------|-----|------|
# | `claim_id` | `TEST-001` | 테스트 청구 ID |
# | `amount` | `100` | 청구 금액 (USD) |
# | `risk_level` | `low` | 위험 등급 |
#
# ### 예상 결과
#
# - **정책 미적용 시**: 도구 호출 성공 (result 반환)
# - **정책 적용 후**: `02-Policy-Enforcement.ipynb`에서 Cedar 정책에 따라 허용/거부

# %%
# Get Gateway token
gateway_cognito_file = SCRIPT_DIR / "gateway_cognito_config.json"
with open(gateway_cognito_file, "r") as f:
    gateway_cognito = json.load(f)

gateway_token = get_bearer_token(
    token_endpoint=gateway_cognito["token_endpoint"],
    client_id=gateway_cognito["client_id"],
    client_secret=gateway_cognito["client_secret"],
    scope=gateway_cognito.get("scope", "")
)

print(f"✓ Gateway token received ({len(gateway_token)} chars)")

# %% [markdown]
# ---
#
# ## 요약
#
# ### 생성된 리소스
#
# ```
# ┌─────────────────────────────────────────────────────────────────────────────────────┐
# │                              생성된 리소스 구조                                       │
# ├─────────────────────────────────────────────────────────────────────────────────────┤
# │                                                                                      │
# │  ┌─────────────────┐                          ┌─────────────────┐                   │
# │  │ Gateway Cognito │                          │ Runtime Cognito │                   │
# │  │ (Inbound Auth)  │                          │ (Outbound Auth) │                   │
# │  └────────┬────────┘                          └────────┬────────┘                   │
# │           │                                            │                            │
# │           │ JWT 검증                                   │ OAuth 토큰 발급             │
# │           ▼                                            │                            │
# │  ┌─────────────────────────────────────────────────────┼───────────────────────┐    │
# │  │                     AgentCore Gateway               │                       │    │
# │  │  ┌─────────────────────────────────────────────────┐│                       │    │
# │  │  │ JWT Authorizer                                  ││                       │    │
# │  │  └─────────────────────────────────────────────────┘│                       │    │
# │  │                                                     │                       │    │
# │  │  ┌─────────────────┐    ┌──────────────────────────┴──┐                     │    │
# │  │  │ RefundToolTarget│    │ RefundMCPServerTarget       │                     │    │
# │  │  │ (Lambda)        │    │ (MCP) ──> Identity ─────────┘                     │    │
# │  │  └────────┬────────┘    └──────────────┬──────────────┘                     │    │
# │  └───────────┼────────────────────────────┼────────────────────────────────────┘    │
# │              │                            │                                          │
# │              ▼                            ▼                                          │
# │  ┌─────────────────┐          ┌─────────────────────────────┐                       │
# │  │ RefundLambda    │          │ AgentCore Runtime           │                       │
# │  │ (Lambda 함수)   │          │ (refund_mcp_server)         │                       │
# │  └─────────────────┘          │  - refund                   │                       │
# │                               │  - get_order                │                       │
# │                               │  - approve_claim            │                       │
# │                               └─────────────────────────────┘                       │
# │                                                                                      │
# └─────────────────────────────────────────────────────────────────────────────────────┘
# ```
#
# ### 설정 완료 항목
#
# | 컴포넌트 | 리소스 | 용도 |
# |----------|--------|------|
# | ✅ Runtime | `refund_mcp_server` | MCP 서버 호스팅 |
# | ✅ Runtime Cognito | User Pool + App Client | Runtime Inbound Auth |
# | ✅ Gateway | `TestGWforPolicyEngine` | MCP 프로토콜 엔드포인트 |
# | ✅ Gateway Cognito | User Pool + App Client | Gateway Inbound Auth |
# | ✅ Identity | `refund-mcp-server-identity` | Outbound Auth 자격 증명 |
# | ✅ MCP Target | `RefundMCPServerTarget` | Gateway → Runtime 연결 |
# | ✅ Lambda Target | `RefundToolTarget` | Gateway → Lambda 연결 (01-Lambda-Target용) |
#
# ### 생성된 설정 파일
#
# | 파일 | 내용 | 용도 |
# |------|------|------|
# | `runtime_config.json` | Runtime ID, ARN, Gateway 정보 | 정책 테스트, 정리 |
# | `cognito_config.json` | Runtime Cognito 자격 증명 | Runtime 직접 호출 |
# | `gateway_cognito_config.json` | Gateway Cognito 자격 증명 | Gateway 호출 |
# | `../01-Lambda-Target/gateway_config.json` | Gateway 전체 설정 | 공유 설정 |
#
# ### 다음 단계
#
# **`02-Policy-Enforcement.ipynb`**를 실행하여:
#
# 1. **Policy Engine 생성** - Gateway에 Cedar 정책 엔진 연결
# 2. **Cedar 정책 테스트** - 다양한 정책 패턴 학습
#    - 문자열 동등 (`== "low"`)
#    - 패턴 매칭 (`like "*low*"`)
#    - OR 조건 (`|| `)
#    - 부정 (`!(...)`)
#    - Principal 태그 (JWT 클레임 기반)
# 3. **정책 모드 전환** - `LOG_ONLY` → `ENFORCE`
